# %% [markdown]
# Q1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# *        - Expression
# "hello"  - Value
# -87.8    - Values
# -        - Expression
# /        - Expression
# +        - Expression
# 6        - Value
#
# Q2. What is the difference between string and variable?
# ANS-> String                                                   Variable
#     1.String is Value representing text                  1.Variable is a name  that stores the value
#     2.exaple- "abc"                                      2.example- name
#
# Q3. Describe three different data types.
# ANS-> Data types is what type of value that is stored in variable, it can be sttring , integer, mathamatical expression, that can be applied to it without causing error. There are many different data types used in Python.
#
# 1. Integer- Integer is number that can be in decimal , positive, negative. e.g 2.3, 43.
#
# 2. String - String is a value representing some text, which can be alphabets, alphanumeric values. e.g "Aman", "dfr23v".
#
# 3. Boolen - These are value which can we either be True or False. The True indicate that the value or condition is valid and False indicate value of condition is not valid
#
# Q4. What is an expression made up of? What do all expressions do?
# ANS Expressions are made up of opreators and opreand with different type mathamatical operators such as * , / , + , -.
# They work with eachother with some set rules and produce some desired results.
#
# + - Addition, add two integer value
# - - Subtraction, it produuce difference between two values
# * - Multiplication, produce result of repeated addition of same number
# / - Division, it vis opposite of multiplication, it is act of splitting of whole into pieces
#
# Q5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
# Ans- An expression is combination of values and function, that is done some opreation by compiler and producting some results. Statement is a standalone text which do not produce any other results.
# - Like in statement spam=10, here "spam" is a variable storing a vale as 10, this variable "spam" , can then be used for some mathameticak opreation changing its value.
#
# Q6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# Ans-> 22
# as bacon=22, here bacon is variable set value as 22, the bacon + 1 was done, this will not change the value of bacon as new value is noty again reassigned to bacon. So Bacon vale remain unchange.
#
# Q7. What should the values of the following two terms be?
# "spam" + "spamspam";
# "spam"* 3;
#
# Ans-> spamspamspam
#       spamspamspam
#
# Q8. Why is eggs a valid variable name while 100 is invalid?
# Ans. In Python, the interpreter do  not allow variable name to start from numeric value.
#
# Q9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?
# 1. int()
# 2. float()
# 3. str()
#
# Q10. Why does this expression cause an error? How can you fix it?
# "I have eaten" + 99 + " burritos."
# ans->"I have eaten 99 burritos."
